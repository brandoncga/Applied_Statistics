# %%
X <- rnorm(30)

# %%
X
# Out:
#  [1] -0.36710221 -0.19991874  1.31409283 -0.82601179  0.93265942 -0.51987094
#  [7]  0.91985782  0.04892421  0.48006415 -0.60164241  0.92134191  0.10739380
# [13] -0.65427482  0.01779285  2.64204820  0.11830217  1.79791826  1.29596563
# [19] -0.31479620 -1.07266813  0.55121535  0.47664942  0.22983863 -1.57874093
# [25] -0.12561115  0.11339230  0.45941635 -1.52491654  0.41424137 -0.28925376

# %%
hist(X)
# Out:
# Plot with title "Histogram of X"

# %%
hist(X,col="Blue")
# Out:
# Plot with title "Histogram of X"
